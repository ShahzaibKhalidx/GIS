# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahzaibKhalidx/GIS/blob/main/GIS_GEOLab_eBird_Downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install ebird-api library

# %%
# !pip install ebird-api

# %% [markdown]
# Import necessary Python libraries

# %%
import os
import pandas as pd
from ebird.api.requests import get_observations
from google.colab import files

# %% [markdown]
# Fill API key and country code

# %%
api_key = "hbo8h6m2h3ii" # @param {"type":"string","placeholder":"Paste API_Key here"}
area = "IT" # @param {"type":"string","placeholder":"Paste Country Code here"}
# Check country code at https://www.iban.com/country-codes for Alpha-2 Code

# %% [markdown]
# Download data and convert to tabular data

# %%
records = get_observations(api_key,area='US')
species=pd.DataFrame(records)
species
# Out:
#     speciesCode                 comName                  sciName      locId  \
# 0        brdowl              Barred Owl              Strix varia  L12875043
# 1        amewoo       American Woodcock           Scolopax minor  L19399437
# 2       belkin1       Belted Kingfisher        Megaceryle alcyon  L50282291
# 3        tuftit         Tufted Titmouse       Baeolophus bicolor  L38398024
# 4        norcar       Northern Cardinal    Cardinalis cardinalis  L38398024
# ..          ...                     ...                      ...        ...
# 795      whoswa            Whooper Swan            Cygnus cygnus  L58853817
# 796      budger              Budgerigar  Melopsittacus undulatus    L839995
# 797     eletro1   Coppery-tailed Trogon          Trogon ambiguus    L303389
# 798     whicoc1          White Cockatoo             Cacatua alba    L392604
# 799     yehcar1  Yellow-headed Caracara      Daptrius chimachima  L58805420
#
# ...

# %% [markdown]
# Download data

# %%
species.to_csv('df.csv')
files.download('df.csv')
